# %%
from pandas import DataFrame,read_csv
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib

print("python version "+ sys.version)
print("panda version" + pd.__version__)
print("matploylib version"+ matplotlib.__version__)
# Out:
# python version 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# panda version1.5.3
# matploylib version3.7.1

# %%
df=pd.read_csv("/content/drive/MyDrive/Python/Record")
df.set_index("TotalSamples")
# Out:
#                     Date                        State  Negative  Positive
# TotalSamples
# 1403          17/04/2020  Andaman and Nicobar Islands    1210.0      12.0
# 2679          24/04/2020  Andaman and Nicobar Islands       NaN      27.0
# 2848          27/04/2020  Andaman and Nicobar Islands       NaN      33.0
# 3754          01/05/2020  Andaman and Nicobar Islands       NaN      33.0
# 6677          16/05/2020  Andaman and Nicobar Islands       NaN      33.0
# ...                  ...                          ...       ...       ...
# 213231        01/06/2020                  West Bengal       NaN    5772.0
# 222726        02/06/2020                  West Bengal       NaN    6168.0
# 232225        03/06/2020                  West Bengal       NaN    6508.0
# 241831        04/06/2020                  West Bengal       NaN    6876.0
# 251517        05/06/2020                  West Bengal       NaN    7303.0
#
# [1775 rows x 4 columns]

# %%
df.dtypes
# Out:
# Date             object
# State            object
# TotalSamples      int64
# Negative        float64
# Positive        float64
# dtype: object

# %%
df.sort_values(['Negative'],ascending=False )
# Out:
#             Date        State  TotalSamples  Negative  Positive
# 1546  06/06/2020   Tamil Nadu        576695  550643.0   30152.0
# 1545  05/06/2020   Tamil Nadu        560673  535254.0   28694.0
# 1544  04/06/2020   Tamil Nadu        544981  517137.0   27256.0
# 1543  03/06/2020   Tamil Nadu        528534  502173.0   25872.0
# 1542  02/06/2020   Tamil Nadu        514433  489258.0   24586.0
# ...          ...          ...           ...       ...       ...
# 1770  01/06/2020  West Bengal        213231       NaN    5772.0
# 1771  02/06/2020  West Bengal        222726       NaN    6168.0
# 1772  03/06/2020  West Bengal        232225       NaN    6508.0
# 1773  04/06/2020  West Bengal        241831       NaN    6876.0
# 1774  05/06/2020  West Bengal        251517       NaN    7303.0
#
# [1775 rows x 5 columns]

# %%
df1=pd.read_csv("/content/drive/MyDrive/Python/Dibatese")
df1.set_index("Insulin")
df1.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df1.count
# Out:
# <bound method DataFrame.count of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
gb=df1.groupby("BloodPressure")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8371e5280db0> in <cell line: 1>()
# ----> 1 gb
#
# NameError: name 'gb' is not defined
